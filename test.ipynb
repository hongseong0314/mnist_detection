# %%
import os
import numpy as np
import matplotlib.pyplot as plt

from utills import *

# %%
# 이미지 출력

path = os.path.join(os.getcwd(), 'data/numbers.jpg')
img = cv2.imread(path)

plt.imshow(img)
plt.show()

# %%
# mnist detection

re_seg_img = mnist_detection(img, verbose=True)
# Out:
# 원본 이미지를 출력합니다.
# 이미지를 분할할 영역을 표시합니다.
# 분할 된 이미지를 출력합니다.

# %%
# img class 분류

data_predit(re_seg_img)
# Out:
# Prediction:  2
# Prediction:  6
# Prediction:  4
# Prediction:  3
# Prediction:  9
# Prediction:  5
# Prediction:  8
